# %% [markdown]
# # 16. N을 입력받은 뒤, 구구단 N단을 출력하는 프로그램을 작성하시오. 출력 형식에 맞춰서 출력하면 된다.[2739]
# 첫째 줄에 N이 주어진다. N은 1보다 크거나 같고, 9보다 작거나 같다.
#
# 출력형식과 같게 N*1부터 N*9까지 출력한다.

# %%
# 런타임 에러 뜸 s 가 string 이니까 그렇게 적어서 하기
N = int(input())

for i in range(1,10,1):
    print("%s * %s = %s" %(N, i,N*i))
# Out:
# 5
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45

# %%
N = int(input())

for i in range(1,10,1):
    print(N ,"*", i ,"=",N*i )
# Out:
# 3
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 3 * 8 = 24
# 3 * 9 = 27

# %% [markdown]
# # 17. 오늘은 2007년 1월 1일 월요일이다. 그렇다면 2007년 x월 y일은 무슨 요일일까? 이를 알아내는 프로그램을 작성하시오.[1924]
# 첫째 줄에 빈 칸을 사이에 두고 x(1 ≤ x ≤ 12)와 y(1 ≤ y ≤ 31)이 주어진다. 참고로 2007년에는 1, 3, 5, 7, 8, 10, 12월은 31일까지, 4, 6, 9, 11월은 30일까지, 2월은 28일까지 있다.
#
# 첫째 줄에 x월 y일이 무슨 요일인지에 따라 SUN, MON, TUE, WED, THU, FRI, SAT중 하나를 출력한다.

# %%
x, y = list(map(int,input().split()))
# Out:
# 5 7

# %%
weak = ['SUN','MON','TUE','WED','THU','FRI','SAT']
day = 0

for i in range(1,x):
    if i == 2:
        n=28
    elif i==4 or i==6 or i==9 or i==11:
        n=30
    else :
        n=31
    day+=n
day+=y
print(weak[day%7])
# Out:
# MON

# %% [markdown]
# # 18. n이 주어졌을 때, 1부터 n까지 합을 구하는 프로그램을 작성하시오.[8393]
# 첫째 줄에 n (1 ≤ n ≤ 10,000)이 주어진다.
#
# 1부터 n까지 합을 출력한다.

# %%
n = int(input())
a=[]
if 1<=n<=10000:
    for i in range(1,n+1,1):
        a.append(i)
        
    print(sum(a))
else :
    print()
# Out:
# 3
# 6

# %% [markdown]
# # 19.N개의 정수가 주어진다. 이때, 최솟값과 최댓값을 구하는 프로그램을 작성하시오.[10818]
# 첫째 줄에 정수의 개수 N (1 ≤ N ≤ 1,000,000)이 주어진다. 둘째 줄에는 N개의 정수를 공백으로 구분해서 주어진다. 모든 정수는 -1,000,000보다 크거나 같고, 1,000,000보다 작거나 같은 정수이다.
#
# 첫째 줄에 주어진 정수 N개의 최솟값과 최댓값을 공백으로 구분해 출력한다.

# %%
N =int(input())
a = list(map(int,input().split()))

print(min(a),max(a))
# 콤마를 하면 알아서 띄어짐, 안띄어지고 싶으면 +로 하기
# Out:
# 3
# 1 2 55 66
# 1 66

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 20.첫째 줄에는 별 1개, 둘째 줄에는 별 2개, N번째 줄에는 별 N개를 찍는 문제[2438]
# 첫째 줄에 N(1 ≤ N ≤ 100)이 주어진다.
#
# 첫째 줄부터 N번째 줄까지 차례대로 별을 출력한다.

# %%
N = int(input())
for i in range(1,N+1,1):
    print("*"*i)
# Out:
# 3
# *
# **
# ***

# %%
print("*"*2)
# Out:
# **

# %% [markdown]
# # 21. 첫째 줄에는 별 1개, 둘째 줄에는 별 2개, N번째 줄에는 별 N개를 찍는 문제 하지만, 오른쪽을 기준으로 정렬한 별(예제 참고)을 출력하시오.[2439]
# 첫째 줄에 N(1 ≤ N ≤ 100)이 주어진다.
#
# 첫째 줄부터 N번째 줄까지 차례대로 별을 출력한다.

# %%
N = int(input())
for i in range(1,N+1,1):
    print(" "*(N-i)+"*"*i)
# Out:
# 4
#    *
#   **
#  ***
# ****

# %%
#질문) 이거는 왜 안될까용 , 앞과 같은 이유
N = int(input())
for i in range(1,N+1,1):
    print(" "*(N-i),"*"*i)
# Out:
# 5
#      *
#     **
#    ***
#   ****
#  *****

# %% [markdown]
# # 22.첫째 줄에는 별 N개, 둘째 줄에는 별 N-1개, ..., N번째 줄에는 별 1개를 찍는 문제[2440]
# 첫째 줄에 N(1 ≤ N ≤ 100)이 주어진다.
#
# 첫째 줄부터 N번째 줄까지 차례대로 별을 출력한다.

# %%
N = int(input())
for i in range(N,0,-1):
    print("*"*i)
# Out:
# 3
# ***
# **
# *

# %% [markdown]
# # 23.첫째 줄에는 별 N개, 둘째 줄에는 별 N-1개, ..., N번째 줄에는 별 1개를 찍는 문제 하지만, 오른쪽을 기준으로 정렬한 별(예제 참고)을 출력하시오.[2441]
# 첫째 줄에 N(1 ≤ N ≤ 100)이 주어진다.
#
# 첫째 줄부터 N번째 줄까지 차례대로 별을 출력한다.

# %%
N = int(input())
for i in range(N,0,-1):
    print(" "*(N-i)+"*"*i)
# Out:
# 3
# ***
#  **
#   *

# %% [markdown]
# # 24. 첫째 줄에는 별 1개, 둘째 줄에는 별 3개, ..., N번째 줄에는 별 2×N-1개를 찍는 문제 별은 가운데를 기준으로 대칭이어야 한다.[2442]
# 첫째 줄에 N(1 ≤ N ≤ 100)이 주어진다.
#
# 첫째 줄부터 N번째 줄까지 차례대로 별을 출력한다.

# %%
# 질문) 이거 왜 안돼?

N = int(input())
for i in range(1,N+1,1):
    print(" "*(N-i) + "*"*(2*i-1) + " "*(N-i))
# Out:
# 5
#     *
#    ***
#   *****
#  *******
# *********

# %%
N = int(input())
for i in range(1,N+1,1):
    print(" "*(N-i) + "*"*(2*i-1))
# Out:
# 5
#     *
#    ***
#   *****
#  *******
# *********

# %% [markdown]
# # 25. 예제를 보고 규칙을 유추한 뒤에 별을 찍어 보세요.[2445]
# 첫째 줄에 N(1 ≤ N ≤ 100)이 주어진다.
#
# 첫째 줄부터 2×N-1번째 줄까지 차례대로 별을 출력한다.

# %%
N = int(input())
for i in range(1,N+1,1):
    print("*"*i+" "*(N-i)+" "*(N-i)+"*"*i)
for i in range(N-1,0,-1):
    print("*"*i+" "*(N-i)+" "*(N-i)+"*"*i)
# Out:
# 5
# *        *
# **      **
# ***    ***
# ****  ****
# **********
# ****  ****
# ***    ***
# **      **
# *        *

# %% [markdown]
# # 26. 예제를 보고 규칙을 유추한 뒤에 별을 찍어 보세요.[2522]
# 첫째 줄에 N(1 ≤ N ≤ 100)이 주어진다.
#
# 첫째 줄부터 2×N-1번째 줄까지 차례대로 별을 출력한다.

# %%
N = int(input())
for i in range(1,N+1,1):
    print(" "*(N-i)+"*"*i)
for i in range(N-1,0,-1):
    print(" "*(N-i)+"*"*i)
# Out:
# 3
#   *
#  **
# ***
#  **
#   *

# %% [markdown]
# # 27. 예제를 보고 규칙을 유추한 뒤에 별을 찍어 보세요.[2446]
# 첫째 줄에 N(1 ≤ N ≤ 100)이 주어진다.
#
# 첫째 줄부터 2×N-1번째 줄까지 차례대로 별을 출력한다.

# %%
N = int(input())
for i in range(N,0,-1):
    print(" "*(N-i) + "*"*(2*i-1))
for i in range(2,N+1,1):
    print(" "*(N-i) + "*"*(2*i-1))
# Out:
# 5
# *********
#  *******
#   *****
#    ***
#     *
#    ***
#   *****
#  *******
# *********

# %% [markdown]
# # 28. 예제를 보고 규칙을 유추한 뒤에 별을 찍어 보세요.[10991]
# 첫째 줄에 N(1 ≤ N ≤ 100)이 주어진다.
#
# 첫째 줄부터 N번째 줄까지 차례대로 별을 출력한다.

# %%
N = int(input())

for i in range(N):
    print(" "*(N-i-1), end=" ")
    print("* "*(i+1))
# Out:
# 3
#    *
#   * *
#  * * *

# %% [markdown]
# # 29. 예제를 보고 규칙을 유추한 뒤에 별을 찍어 보세요.[10992]
# 첫째 줄에 N(1 ≤ N ≤ 100)이 주어진다.
#
# 첫째 줄부터 N번째 줄까지 차례대로 별을 출력한다.

# %%
N = int(input())
for i in range(N):
    print(" "*(N-i-1),end=" ")
    print("* "*(i))
for i in range(1) :
    print("*" *(2*N-1))
# Out:
# 3
#
#   *
#  * *
# *****

# %%
# 그치만 안돼,, 머쓱
N = int(input())
for i in range(1,N+1):
    if i==1:
        print(' '*(N-1)+'*')        
    elif i==N:
        print('*'*(2*N-1))
    else:
        print(' '*(N-i)+'*'+' '*(2*i-3)+'*')
# Out:
# 3
#   *
#  * *
# *****
